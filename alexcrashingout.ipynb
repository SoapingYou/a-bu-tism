# %%
#baseline constants
baseline_trial_num = 10
error_freq = 1
speed_noise_amplitude =0.1
headdir_noise_amplitude = 0.05
ts = 0.001
sim=20000
deltahead=2.4

#running trials!
random.setstate(rand_state)
master.baseline(1, error_freq=error_freq,speed_noise_amplitude=speed_noise_amplitude,
                headdir_noise_amplitude=headdir_noise_amplitude, ts=ts, sim=sim, deltahead=deltahead)
# Out:
# the mouse moved this far: 1074.768999156258
# [[ 327.52475643 1023.64834561]]
# [ -843.97232722 -1024.40853096]

# %%
master.trimmed_sim_pos[0:5]
# Out:
# array([[ 5.49991037e-04,  3.28045742e-06],
#        [ 1.74238543e-03, -2.80342345e-06],
#        [ 2.41998820e-03, -1.41623286e-06],
#        [ 2.48422651e-03,  8.95589218e-08],
#        [ 2.90230977e-03,  1.03143725e-05]])

# %%
f.close()

# %%
from phases_to_location import phasesToLocation1DProgressive
from optimized_phases_to_location import phasesToLocation1DOptimize

df = pd.read_csv('phases_clean.csv')
df
# Out:
#           ts        x1        x2        x3        x4        x5        x6  \
# 0          0  0.000138  0.000083  0.000051  0.000031  0.000019  0.000011
# 1          1  0.000438  0.000266  0.000161  0.000098  0.000059  0.000036
# 2          2  0.000608  0.000369  0.000223  0.000135  0.000082  0.000050
# 3          3  0.000624  0.000378  0.000229  0.000139  0.000084  0.000051
# 4          4  0.000728  0.000441  0.000267  0.000162  0.000098  0.000060
# ...      ...       ...       ...       ...       ...       ...       ...
# 19995  19995  5.652458  5.520127  1.822335  4.722037  4.004238  1.094014
# 19996  19996  5.650976  5.519229  1.821791  4.721707  4.004038  1.093893
# 19997  19997  5.649635  5.518416  1.821298  4.721409  4.003857  1.093783
# 19998  19998  5.648409  5.517673  1.820848  4.721136  4.003692  1.093683
# 19999  19999  5.647381  5.517050  1.820470  4.720907  4.003553  1.093599
#
#              x7        x8        x9  ...            y1            y2  \
# ...

# %%
sim_pos_csv = np.zeros((20_000, 2))

data = np.zeros((10, 2))
data[:, 0] = 25 * 1.65 ** np.arange(0, 10)

for i, row in enumerate(df.iterrows()):
    data[:, 1] = row[1]['x1':'x10'].to_numpy()
    x = phasesToLocation1DProgressive(data)
    data[:, 1] = row[1]['y1':'y10'].to_numpy()
    y = phasesToLocation1DProgressive(data)
    sim_pos_csv[i] = [x, y]

# %%
plt.plot(sim_pos_csv)
plt.figure()
plt.plot(master.trimmed_sim_pos)

# %%
# %matplotlib inline
#plot error over time
x = np.arange(sim) # this only works now in this specific case bc error_freq=1
y = np.mean(baseline_errors_over_time, axis=0)
y_list = baseline_errors_over_time

#y=master.error_over_time_i
for i in range(1):
    plt.plot(x,y_list[i],label=i)
plt.xlabel('timestep')
plt.ylabel('mean error (cm)')
plt.legend()
plt.show()

# %%
positions = np.zeros(5)
df = np.zeros((10, 2))
df[:, 0] = s_is
for i in range(5):
    df[:, 1] = xphases[i]
    positions[i] = phasesToLocation1DProgressive(df)

# %%
plt.ticklabel_format(useOffset=False)
plt.plot(t, positions)
plt.xticks(t)
''
